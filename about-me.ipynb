# %%
# About Me
# Please fill in the following details.

name = "Shyam Sunder Chiliveri"
reason = "I’m fascinated by how AI and data-driven insights can solve complex problems, optimize processes, and uncover patterns that aren’t visible at first glance."
fun_fact = "I come from a materials engineering background, and my goal for this course is to bridge my expertise in metallurgy with AI and data science to create innovative solutions in materials research and development."

print(f"Hi! My name is {name}. I’m excited to learn because {reason} A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Shyam Sunder Chiliveri. I’m excited to learn because I’m fascinated by how AI and data-driven insights can solve complex problems, optimize processes, and uncover patterns that aren’t visible at first glance. A fun fact about me is: I come from a materials engineering background, and my goal for this course is to bridge my expertise in metallurgy with AI and data science to create innovative solutions in materials research and development..
